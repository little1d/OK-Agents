# %%
from okagents.agents import KGAgent
import os
import logging
from camel.models import ModelFactory
from camel.types import ModelPlatformType, ModelType
from okagents.config import Config
from camel.configs import ChatGPTConfig

# %%
config = Config()
# creating the model
deepseek = ModelFactory.create(
    model_platform=ModelPlatformType.DEEPSEEK,
    api_key=config.DEEPSEEK_API_KEY,
    url=config.DEEPSEEK_API_BASE,
    model_type=ModelType.DEEPSEEK_CHAT,
    model_config_dict={"max_tokens": 4096},
)

# %%
kg_agent = KGAgent(deepseek)

# %%
# ---------------------------------- test str ----------------------------------

test_data = """Large Language Models (LLMs) have shown remarkable capabilities in various tasks. 
However, their reasoning abilities still need improvement. Recent research focuses on 
reinforcement learning approaches to enhance LLM reasoning. Key challenges include 
reward signal design and efficient training algorithms."""

# %%
results = kg_agent.pre_parse(test_data)
print(results)
# Out:
# Parsed content as plain text: Large Language Models (LLMs) have shown remarkable capabilities in various tasks.
# However, their reasoning abilities still need improvement. Recent research focuses on
# reinforcement learning approaches to enhance LLM reasoning. Key challenges include
# reward signal design and efficient training algorithms.
# ### Extracted Nodes and Relationships
#
# #### Nodes:
# 1. **Node(id='Large Language Models', type='Concept')**
# 2. **Node(id='Reasoning Abilities', type='Concept')**
# 3. **Node(id='Reinforcement Learning', type='Concept')**
# 4. **Node(id='Reward Signal Design', type='Challenge')**
# 5. **Node(id='Efficient Training Algorithms', type='Challenge')**
#
# #### Relationships:
# 1. **Relationship(subj=Node(id='Large Language Models', type='Concept'), obj=Node(id='Reasoning Abilities', type='Concept'), type='Has')**
#    - Explanation: Large Language Models possess reasoning abilities.
#
# 2. **Relationship(subj=Node(id='Reasoning Abilities', type='Concept'), obj=Node(id='Reinforcement Learning', type='Concept'), type='ImprovedBy')**
#    - Explanation: Reasoning abilities are improved by reinforcement learning approaches.
#
# 3. **Relationship(subj=Node(id='Reinforcement Learning', type='Concept'), obj=Node(id='Reward Signal Design', type='Challenge'), type='Faces')**
#    - Explanation: Reinforcement learning faces challenges in reward signal design.
#
# 4. **Relationship(subj=Node(id='Reinforcement Learning', type='Concept'), obj=Node(id='Efficient Training Algorithms', type='Challenge'), type='Faces')**
#    - Explanation: Reinforcement learning also faces challenges in efficient training algorithms.
#
# ### Output Formatting
#
# ```python
# # Nodes
# nodes = [
#     Node(id='Large Language Models', type='Concept'),
#     Node(id='Reasoning Abilities', type='Concept'),
#     Node(id='Reinforcement Learning', type='Concept'),
#     Node(id='Reward Signal Design', type='Challenge'),
#     Node(id='Efficient Training Algorithms', type='Challenge')
# ]
#
# # Relationships
# relationships = [
#     Relationship(subj=Node(id='Large Language Models', type='Concept'), obj=Node(id='Reasoning Abilities', type='Concept'), type='Has'),
#     Relationship(subj=Node(id='Reasoning Abilities', type='Concept'), obj=Node(id='Reinforcement Learning', type='Concept'), type='ImprovedBy'),
#     Relationship(subj=Node(id='Reinforcement Learning', type='Concept'), obj=Node(id='Reward Signal Design', type='Challenge'), type='Faces'),
#     Relationship(subj=Node(id='Reinforcement Learning', type='Concept'), obj=Node(id='Efficient Training Algorithms', type='Challenge'), type='Faces')
# ]
# ```
#
# This structured data can now be easily validated against the provided code.

# %%
# ---------------------------------- test remote url ----------------------------------
test_url = "https://github.com/PRIME-RL/PRIME"

results = kg_agent.pre_parse(content=test_url)
print(results)
# Out:
# Parsed content from URL: https://github.com/PRIME-RL/PRIME
# ### Extracted Nodes and Relationships:
#
# #### Nodes:
# 1. **Node(id='PRIME-RL', type='Project')**
# 2. **Node(id='PRIME Public', type='Project')**
# 3. **Node(id='Scalable RL solution', type='Technology')**
# 4. **Node(id='advanced reasoning', type='Capability')**
# 5. **Node(id='language models', type='Technology')**
# 6. **Node(id='Apache-2.0 license', type='License')**
# 7. **Node(id='1.4k stars', type='Metric')**
# 8. **Node(id='85 forks', type='Metric')**
# 9. **Node(id='Branches', type='Repository Feature')**
# 10. **Node(id='Tags', type='Repository Feature')**
# 11. **Node(id='Activity', type='Repository Feature')**
# 12. **Node(id='Notifications', type='Feature')**
#
# #### Relationships:
# 1. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='PRIME Public', type='Project'), type='IsRelatedTo')**
# 2. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='Scalable RL solution', type='Technology'), type='Uses')**
# 3. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='advanced reasoning', type='Capability'), type='Enables')**
# 4. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='language models', type='Technology'), type='Targets')**
# 5. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='Apache-2.0 license', type='License'), type='IsLicensedUnder')**
# 6. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='1.4k stars', type='Metric'), type='HasMetric')**
# 7. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='85 forks', type='Metric'), type='HasMetric')**
# 8. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='Branches', type='Repository Feature'), type='HasFeature')**
# 9. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='Tags', type='Repository Feature'), type='HasFeature')**
# 10. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='Activity', type='Repository Feature'), type='HasFeature')**
# 11. **Relationship(subj=Node(id='PRIME-RL', type='Project'), obj=Node(id='Notifications', type='Feature'), type='HasFeature')**
#
# ### Explanation:
# - **Nodes** represent distinct entities such as the project names, technologies, capabilities, licenses, metrics, and repository features.
# - **Relationships** describe how these entities are connected, such as the project using a specific technology, being licensed under a particular license, or having certain repository features.
#
# This structured data can now be used to build a graph that visually represents the relationships and connections between the different entities mentioned in the content.

# %%
# ---------------------------------- test pdf ----------------------------------
# 填写你自己的 pdf_path，不建议测试，耗时太久了
test_pdf_path = "/Users/little1d/Desktop/Code/Knowledge-Agent/data/prime.pdf"
kg_agent.parse(content=test_pdf_path)
# Out:
# Parsed content from file: /Users/little1d/Desktop/Code/Knowledge-Agent/data/prime.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 # ---------------------------------- test pdf ----------------------------------
#       2 # 填写你自己的 pdf_path，不建议测试，耗时太久了
#       3 test_pdf_path = "/Users/little1d/Desktop/Code/Knowledge-Agent/data/prime.pdf"
# ----> 4 kg_agent.parse(content=test_pdf_path)
#
# File ~/Desktop/Code/Knowledge-Agent/okagents/agents/kg_agent.py:133, in KGAgent.parse(self, content)
#     124 """
#     125 解析文件，并转换为 node 和 relation，再将知识图谱元素保存到 Neo4j
#     126
#    (...)
#     130     max_characters (int): 分块的最大字符数，默认为500
#     131 """
#     132 # 预处理内容
# --> 133 pre_parsed = self.pre_parse(content=content)
#     134 # validate
#     135 validated_content = self.validate(content=pre_parsed)
#
# File ~/Desktop/Code/Knowledge-Agent/okagents/agents/kg_agent.py:71, in KGAgent.pre_parse(self, content, prompt)
#      67 is_url = all([parsed_url.scheme, parsed_url.netloc])
#      69 if is_url or os.path.exists(content):
#      70     # URL 或文件路径的处理
# ---> 71     return self._process_url_or_file(content, is_url)
#      72 else:
#      73     # 纯文本的处理
#      74     return self._process_plain_text(content)
#
# File ~/Desktop/Code/Knowledge-Agent/okagents/agents/kg_agent.py:105, in KGAgent._process_url_or_file(self, path, is_url)
#     103 results = []
#     104 for chunk in chunk_elements:
# --> 105     parsed = self.camel_kg_agent.run(
#     106         element=chunk,
#     107         parse_graph_elements=False,
#     108     )
#     109     results.append(parsed)
#     111 return "\n".join(results)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/agents/knowledge_graph_agent.py:168, in KnowledgeGraphAgent.run(self, element, parse_graph_elements)
#     163 knowledge_graph_prompt = TextPrompt(text_prompt)
#     164 knowledge_graph_generation = knowledge_graph_prompt.format(
#     165     task=str(element)
#     166 )
# --> 168 response = self.step(input_message=knowledge_graph_generation)
#     170 content = response.msg.content
#     172 if parse_graph_elements:
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/agents/chat_agent.py:612, in ChatAgent.step(self, input_message, response_format)
#     609 self.update_memory(input_message, OpenAIBackendRole.USER)
#     611 try:
# --> 612     return self._handle_step(response_format, self.single_iteration)
#     613 finally:
#     614     if model_response_format_modified:
#     615         # Reset model config back to original state
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/agents/chat_agent.py:682, in ChatAgent._handle_step(self, response_format, single_step)
#     673     openai_messages.append(usr_msg)
#     675 # Process model response
#     676 (
#     677     response,
#     678     output_messages,
#     679     finish_reasons,
#     680     usage_dict,
#     681     response_id,
# --> 682 ) = self._step_model_response(openai_messages, num_tokens)
#     684 # Try to parse structured output to return a Pydantic object
#     685 if inject_prompt_for_structured_output and isinstance(
#     686     response, ChatCompletion
#     687 ):
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/agents/chat_agent.py:1099, in ChatAgent._step_model_response(self, openai_messages, num_tokens)
#    1097 for _ in range(len(self.model_backend.models)):
#    1098     try:
# -> 1099         response = self.model_backend.run(openai_messages)
#    1100         break
#    1101     except Exception as exc:
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/models/model_manager.py:201, in ModelManager.run(self, messages)
#     199 # Pass all messages to the selected model and get the response
#     200 try:
# --> 201     response = self.current_model.run(messages)
#     202 except Exception as exc:
#     203     logger.error(f"Error processing with model: {self.current_model}")
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/models/base_model.py:49, in ModelBackendMeta.__new__.<locals>.wrapped_run(self, messages, *args, **kwargs)
#      45 def wrapped_run(
#      46     self, messages: List[OpenAIMessage], *args, **kwargs
#      47 ):
#      48     messages = self.preprocess_messages(messages)
# ---> 49     return original_run(self, messages, *args, **kwargs)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/camel/models/deepseek_model.py:142, in DeepSeekModel.run(self, messages)
#     139         if key in self.model_config_dict:
#     140             del self.model_config_dict[key]
# --> 142 response = self._client.chat.completions.create(
#     143     messages=messages,
#     144     model=self.model_type,
#     145     **self.model_config_dict,
#     146 )
#     148 # Handle reasoning content with <think> tags at the beginning
#     149 if (
#     150     self.model_type
#     151     in [
#    (...)
#     155     == "true"
#     156 ):
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/openai/_base_client.py:1296, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1282 def post(
#    1283     self,
#    1284     path: str,
#    (...)
#    1291     stream_cls: type[_StreamT] | None = None,
#    1292 ) -> ResponseT | _StreamT:
#    1293     opts = FinalRequestOptions.construct(
#    1294         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1295     )
# -> 1296     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/openai/_base_client.py:973, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     970 else:
#     971     retries_taken = 0
# --> 973 return self._request(
#     974     cast_to=cast_to,
#     975     options=options,
#     976     stream=stream,
#     977     stream_cls=stream_cls,
#     978     retries_taken=retries_taken,
#     979 )
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/openai/_base_client.py:1009, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1008 try:
# -> 1009     response = self._client.send(
#    1010         request,
#    1011         stream=stream or self._should_stream_response_body(request=request),
#    1012         **kwargs,
#    1013     )
#    1014 except httpx.TimeoutException as err:
#    1015     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_client.py:940, in Client.send(self, request, stream, auth, follow_redirects)
#     938 except BaseException as exc:
#     939     response.close()
# --> 940     raise exc
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_client.py:934, in Client.send(self, request, stream, auth, follow_redirects)
#     932 try:
#     933     if not stream:
# --> 934         response.read()
#     936     return response
#     938 except BaseException as exc:
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_models.py:815, in Response.read(self)
#     811 """
#     812 Read and return the response content.
#     813 """
#     814 if not hasattr(self, "_content"):
# --> 815     self._content = b"".join(self.iter_bytes())
#     816 return self._content
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_models.py:831, in Response.iter_bytes(self, chunk_size)
#     829 chunker = ByteChunker(chunk_size=chunk_size)
#     830 with request_context(request=self._request):
# --> 831     for raw_bytes in self.iter_raw():
#     832         decoded = decoder.decode(raw_bytes)
#     833         for chunk in chunker.decode(decoded):
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_models.py:885, in Response.iter_raw(self, chunk_size)
#     882 chunker = ByteChunker(chunk_size=chunk_size)
#     884 with request_context(request=self._request):
# --> 885     for raw_stream_bytes in self.stream:
#     886         self._num_bytes_downloaded += len(raw_stream_bytes)
#     887         for chunk in chunker.decode(raw_stream_bytes):
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_client.py:127, in BoundSyncStream.__iter__(self)
#     126 def __iter__(self) -> typing.Iterator[bytes]:
# --> 127     for chunk in self._stream:
#     128         yield chunk
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpx/_transports/default.py:116, in ResponseStream.__iter__(self)
#     114 def __iter__(self) -> typing.Iterator[bytes]:
#     115     with map_httpcore_exceptions():
# --> 116         for part in self._httpcore_stream:
#     117             yield part
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_sync/http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_sync/http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_sync/http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/ssl.py:1258, in SSLSocket.recv(self, buflen, flags)
#    1254     if flags != 0:
#    1255         raise ValueError(
#    1256             "non-zero flags not allowed in calls to recv() on %s" %
#    1257             self.__class__)
# -> 1258     return self.read(buflen)
#    1259 else:
#    1260     return super().recv(buflen, flags)
#
# File ~/Desktop/Dev_env/miniconda3/envs/bo/lib/python3.10/ssl.py:1131, in SSLSocket.read(self, len, buffer)
#    1129         return self._sslobj.read(len, buffer)
#    1130     else:
# -> 1131         return self._sslobj.read(len)
#    1132 except SSLError as x:
#    1133     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
